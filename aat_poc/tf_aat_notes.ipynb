# %% [markdown]
# # Tensorflow - AAT notes

# %% [markdown]
# ## import libraries

# %%
import tensorflow as tf
import numpy as np

print("TensorFlow version: ",tf.version.VERSION)
# Out:
# TensorFlow version:  2.3.0

# %% [markdown]
# tensors

# %%
rank_0_tensor = tf.constant(4)
print(rank_0_tensor)
# Out:
# tf.Tensor(4, shape=(), dtype=int32)

# %%
rank_1_tensor = tf.constant([2.0, 3.0, 4.0])
print(rank_1_tensor)
# Out:
# tf.Tensor([2. 3. 4.], shape=(3,), dtype=float32)

# %%
rank_2_tensor = tf.constant([[1, 2],
                             [3, 4],
                             [5, 6]], dtype=tf.float16)
print(rank_2_tensor)
# Out:
# tf.Tensor(
# [[1. 2.]
#  [3. 4.]
#  [5. 6.]], shape=(3, 2), dtype=float16)

# %% [markdown]
# ### convet Tensor to numpy array

# %%
np.array(rank_2_tensor)
# Out:
# array([[1., 2.],
#        [3., 4.],
#        [5., 6.]], dtype=float16)

# %%
rank_2_tensor.numpy()
# Out:
# array([[1., 2.],
#        [3., 4.],
#        [5., 6.]], dtype=float16)

# %% [markdown]
# variables

# %% [markdown]
# operations

# %% [markdown]
# Slicing

# %% [markdown]
# indexing

# %% [markdown]
# creatin N dimentional tensors

# %% [markdown]
# features

# %% [markdown]
# reading writing files - serialization

# %% [markdown]
# Tf messages

# %% [markdown]
# TFrecords

# %% [markdown]
# writing files - serializing

# %% [markdown]
# reading serialized files

# %% [markdown]
# CSV

# %%
#code here

# %% [markdown]
# #references

# %% [markdown]
# ## gitgub
#
# https://github.com/googlecloudplatform/training-data-analyst
#
#
#
# ## intro to tensorflow - coursera
#
# https://github.com/GoogleCloudPlatform/training-data-analyst/tree/master/courses/machine_learning/deepdive2/introduction_to_tensorflow
