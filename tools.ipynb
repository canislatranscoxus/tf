# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt

# %%
x = [i for i in range(0, 10) ]
y = [i**2 for i in range(0, 10) ]

# %%
print( 'x: {}'.format( x ) )
print( 'y: {}'.format( y ) )
# Out:
# x: [0, 1, 2, 3, 4]
# y: [0, 1, 4, 9, 16]

# %%
plt.plot( x )

# %%
plt.plot( x, y )
plt.xlabel( 'x- integers' )
plt.ylabel( 'y- squares' )
plt.show()

# %% [markdown]
# ## plot series

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      label - tag for the line
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))
    
    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %%
# ejemplo
plot_series( time=x, series=y, format="-", start=0, end=None)

# %% [markdown]
# ### Download Files from url

# %%
# !wget --no-check-certificate \
    "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip" \
    -O "/tmp/cats-and-dogs.zip"

# %% [markdown]
# ### Unzip decompress a zip file

# %%
local_zip = '/tmp/cats-and-dogs.zip'
zip_ref   = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# ### Print a table in the notebook

# %%
# the easy way

def print_table_pd( table, columns ):
    df = pd.DataFrame( table, columns= columns  )
    display( df )
    return df

# %%
import pandas as pd
data = [[1, 2], [3, 4]]
pd.DataFrame(data, columns=["Foo", "Bar"])
# Out:
#    Foo  Bar
# 0    1    2
# 1    3    4

# %%
# the hard way

def print_table_html( table, columns ):
    
    header = '<tr><td>{}</td></tr>'.format('</td><td>'.join(str(_) for _ in columns ))
   
    body = '<tr>{}</tr>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in table)
       )
    
    display(HTML(
   '<table>{}{}</table>'.format( header, body )
   ))
